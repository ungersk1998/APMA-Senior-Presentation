# %%
import pandas as pd
import numpy as np

# %%
# read in features data, extracting only the 55 rows corresponding to unique SBAs
nineties = pd.read_csv('nineties_withtens.csv')
nineties = nineties.iloc[:55]
thousands = pd.read_csv('thousands_withtens.csv')
thousands = thousands.iloc[:55]
tens_w_nineties = pd.read_csv('tens_withnineties.csv')
tens_w_nineties = tens_w_nineties.iloc[:55]
tens_w_thousands = pd.read_csv('tens_withthousands.csv')
tens_w_thousands = tens_w_thousands.iloc[:55]

response_rates = pd.read_csv('participationrates2000_2010.csv')

# read in tract numbers as strings to search with later
tract_neighborhood = pd.read_csv('nyc2010census_tabulation_equiv.csv',converters={'tract_num': lambda x: str(x)})

sba_neighborhood = pd.read_csv('sba_to_neigh_codes.csv')

# %%
# Extract response rates by borough
manhattan_rates = response_rates[response_rates['geo_id'][:].str[0:5] == '36061'][:]
queens_rates = response_rates[response_rates['geo_id'][:].str[0:5] == '36081'][:]
brooklyn_rates = response_rates[response_rates['geo_id'][:].str[0:5] == '36047'][:]
bronx_rates = response_rates[response_rates['geo_id'][:].str[0:5] == '36005'][:]
staten_island_rates = response_rates[response_rates['geo_id'][:].str[0:5] == '36085'][:]

# %%
sba_response_rate_2000 = []
sba_response_rate_2010 = []

# match sba to neighborhood code 
for sba in thousands['sub-burough'][:]:
    sba = str(sba)
    print(sba)
    borough = sba[0]
    
    neigh_codes = sba_neighborhood[sba][:].dropna()
    print("Number of neighborhood codes in SBA:",len(neigh_codes))
    sba_rate_2000 = 0
    sba_rate_2010 = 0
    number_of_codes = 0

    # extract corresponding tract numbers
    for code in neigh_codes:

        match_bool = tract_neighborhood['neighborhood_code'][:].str.match(code)
        tract_nums = tract_neighborhood[match_bool]['tract_num']
        print("Neighborhood code:",code)
        print("Number of tracts in neighborhood code:",len(tract_nums))
        code_rate_2000 = 0
        code_rate_2010 = 0
        number_of_tracts = 0

        if sum(match_bool)==0:
            print("No matches for code",code)
            continue
        else:
            # extract 2010 response rates by unique geoid      
            if borough=='1': # bronx
                stem = '36005'

                for tract in tract_nums:

                    geoid = stem+tract
                    tract_rate_2000 = list(bronx_rates[bronx_rates['geo_id'][:] == geoid]['2000_rate'])
                    tract_rate_2010 = list(bronx_rates[bronx_rates['geo_id'][:] == geoid]['2010_rate'])

                    if len(tract_rate_2000) == 0:
                        print("For neighborhood code",code,", no tracts match geoid",geoid)
                        continue
                    else:
                        tract_rate_2000 = tract_rate_2000[0]
                        tract_rate_2010 = tract_rate_2010[0]

                    # handle erroneous response rates
                    if tract_rate_2000 > 1:
                        tract_rate_2000 = 1
                    
                    if tract_rate_2010 > 1:
                        tract_rate_2010 = 1

                    number_of_tracts += 1
                    code_rate_2000 += tract_rate_2000
                    code_rate_2010 += tract_rate_2010

            elif borough=='2': # brookyln
                stem = '36047'

                for tract in tract_nums:

                    geoid = stem+tract
                    tract_rate_2000 = list(brooklyn_rates[brooklyn_rates['geo_id'][:] == geoid]['2000_rate'])
                    tract_rate_2010 = list(brooklyn_rates[brooklyn_rates['geo_id'][:] == geoid]['2010_rate'])

                    if len(tract_rate_2000) == 0:
                        print("For neighborhood code",code,", no tracts match geoid",geoid)
                        continue
                    else:
                        tract_rate_2000 = tract_rate_2000[0]
                        tract_rate_2010 = tract_rate_2010[0]

                    # handle erroneous response rates
                    if tract_rate_2000 > 1:
                        tract_rate_2000 = 1
                    
                    if tract_rate_2010 > 1:
                        tract_rate_2010 = 1

                    number_of_tracts += 1
                    code_rate_2000 += tract_rate_2000
                    code_rate_2010 += tract_rate_2010
                    
            elif borough=='3': # manhattan
                stem = '36061'

                for tract in tract_nums:

                    geoid = stem+tract
                    tract_rate_2000 = list(manhattan_rates[manhattan_rates['geo_id'][:] == geoid]['2000_rate'])
                    tract_rate_2010 = list(manhattan_rates[manhattan_rates['geo_id'][:] == geoid]['2010_rate'])

                    if len(tract_rate_2000) == 0:
                        print("For neighborhood code",code,", no tracts match geoid",geoid)
                        continue
                    else:
                        tract_rate_2000 = tract_rate_2000[0]
                        tract_rate_2010 = tract_rate_2010[0]

                    # handle erroneous response rates
                    if tract_rate_2000 > 1:
                        tract_rate_2000 = 1
                    
                    if tract_rate_2010 > 1:
                        tract_rate_2010 = 1

                    number_of_tracts += 1
                    code_rate_2000 += tract_rate_2000
                    code_rate_2010 += tract_rate_2010
                    
            elif borough=='4': # queens
                stem = '36081'

                for tract in tract_nums:

                    geoid = stem+tract 
                    tract_rate_2000 = list(queens_rates[queens_rates['geo_id'][:] == geoid]['2000_rate'])
                    tract_rate_2010 = list(queens_rates[queens_rates['geo_id'][:] == geoid]['2010_rate'])

                    if len(tract_rate_2000) == 0:
                        print("For neighborhood code",code,", no tracts match geoid",geoid)
                        continue
                    else:
                        tract_rate_2000 = tract_rate_2000[0]
                        tract_rate_2010 = tract_rate_2010[0]

                    # handle erroneous response rates
                    if tract_rate_2000 > 1:
                        tract_rate_2000 = 1
                    
                    if tract_rate_2010 > 1:
                        tract_rate_2010 = 1

                    number_of_tracts += 1
                    code_rate_2000 += tract_rate_2000
                    code_rate_2010 += tract_rate_2010

            elif borough=='5': # staten island
                stem = '36085'

                for tract in tract_nums:

                    geoid = stem+tract
                    tract_rate_2000 = list(staten_island_rates[staten_island_rates['geo_id'][:] == geoid]['2000_rate'])
                    tract_rate_2010 = list(staten_island_rates[staten_island_rates['geo_id'][:] == geoid]['2010_rate'])

                    if len(tract_rate_2000) == 0:
                        print("For neighborhood code",code,", no tracts match geoid",geoid)
                        continue
                    else:
                        tract_rate_2000 = tract_rate_2000[0]
                        tract_rate_2010 = tract_rate_2010[0]

                    # handle erroneous response rates
                    if tract_rate_2000 > 1:
                        tract_rate_2000 = 1
                    
                    if tract_rate_2010 > 1:
                        tract_rate_2010 = 1

                    number_of_tracts += 1
                    code_rate_2000 += tract_rate_2000
                    code_rate_2010 += tract_rate_2010


            if number_of_tracts == 0:
                print("For SBA",sba,"and neighborhood code",code,
                      ", there are zero matched tracts, so cannot calculate code_rate.")
            else:
                number_of_codes += 1
                code_rate_2000 = code_rate_2000 / number_of_tracts
                code_rate_2010 = code_rate_2010 / number_of_tracts
                sba_rate_2000 += code_rate_2000
                sba_rate_2010 += code_rate_2010

    if number_of_codes == 0:
        print("No codes matched for SBA",sba)
        continue
    else:
        sba_rate_2000 = sba_rate_2000 / number_of_codes
        sba_rate_2010 = sba_rate_2010 / number_of_codes
        sba_response_rate_2000.append(sba_rate_2000)
        sba_response_rate_2010.append(sba_rate_2010)
        print("2000 SBA rate for SBA",sba,"is",sba_rate_2000)
        print("2010 SBA rate for SBA",sba,"is",sba_rate_2010)

# append response values to data to get datasets for modeling
import copy

dataset2000 = copy.deepcopy(nineties)
dataset2000['sba_response_rate_2000'] = sba_response_rate_2000
dataset2000 = dataset2000.set_index('sub-burough')

dataset2010 = copy.deepcopy(thousands)
dataset2010['sba_response_rate_2010'] = sba_response_rate_2010
dataset2010 = dataset2010.set_index('sub-burough')
# Out:
# 201
# Number of neighborhood codes in SBA: 4
# Neighborhood code: BK76
# Number of tracts in neighborhood code: 12
# For neighborhood code BK76 , no tracts match geoid 36047056100
# Neighborhood code: BK73
# Number of tracts in neighborhood code: 13
# Neighborhood code: BK90
# Number of tracts in neighborhood code: 10
# For neighborhood code BK90 , no tracts match geoid 36047044900
# Neighborhood code: BK72
# Number of tracts in neighborhood code: 7
# 2000 SBA rate for SBA 201 is 0.5378726828726829
# 2010 SBA rate for SBA 201 is 0.5828574203574204
# 202
# Number of neighborhood codes in SBA: 4
# Neighborhood code: BK69
# Number of tracts in neighborhood code: 10
# Neighborhood code: BK68
# Number of tracts in neighborhood code: 10
# For neighborhood code BK68 , no tracts match geoid 36047021100
# Neighborhood code: BK38
# Number of tracts in neighborhood code: 12
# For neighborhood code BK38 , no tracts match geoid 36047001500
# Neighborhood code: BK09
# Number of tracts in neighborhood code: 6
# For neighborhood code BK09 , no tracts match geoid 36047000501
# For neighborhood code BK09 , no tracts match geoid 36047000502
# 2000 SBA rate for SBA 202 is 0.5421136363636363
# 2010 SBA rate for SBA 202 is 0.6615454545454544
# 203
# Number of neighborhood codes in SBA: 2
# Neighborhood code: BK75
# Number of tracts in neighborhood code: 19
# For neighborhood code BK75 , no tracts match geoid 36047123700
# Neighborhood code: BK35
# Number of tracts in neighborhood code: 18
# 2000 SBA rate for SBA 203 is 0.4361111111111111
# 2010 SBA rate for SBA 203 is 0.5008333333333334
# 204
# Number of neighborhood codes in SBA: 2
# Neighborhood code: BK77
# Number of tracts in neighborhood code: 13
# Neighborhood code: BK78
# Number of tracts in neighborhood code: 21
# For neighborhood code BK78 , no tracts match geoid 36047048500
# 2000 SBA rate for SBA 204 is 0.5412115384615386
# 2010 SBA rate for SBA 204 is 0.5578653846153847
# 205
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BK83
# Number of tracts in neighborhood code: 16
# Neighborhood code: BK82
# Number of tracts in neighborhood code: 27
# For neighborhood code BK82 , no tracts match geoid 36047110400
# For neighborhood code BK82 , no tracts match geoid 36047111600
# For neighborhood code BK82 , no tracts match geoid 36047119800
# Neighborhood code: BK93
# Number of tracts in neighborhood code: 2
# For neighborhood code BK93 , no tracts match geoid 36047105801
# For neighborhood code BK93 , no tracts match geoid 36047105804
# For SBA 205 and neighborhood code BK93 , there are zero matched tracts, so cannot calculate code_rate.
# 2000 SBA rate for SBA 205 is 0.48510416666666667
# 2010 SBA rate for SBA 205 is 0.5245833333333334
# 206
# Number of neighborhood codes in SBA: 2
# Neighborhood code: BK33
# Number of tracts in neighborhood code: 12
# For neighborhood code BK33 , no tracts match geoid 36047005300
# Neighborhood code: BK37
# Number of tracts in neighborhood code: 20
# For neighborhood code BK37 , no tracts match geoid 36047011900
# 2000 SBA rate for SBA 206 is 0.5897846889952154
# 2010 SBA rate for SBA 206 is 0.6654066985645932
# 207
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BK32
# Number of tracts in neighborhood code: 15
# For neighborhood code BK32 , no tracts match geoid 36047001800
# Neighborhood code: BK34
# Number of tracts in neighborhood code: 16
# For neighborhood code BK34 , no tracts match geoid 36047008600
# Neighborhood code: BK40
# Number of tracts in neighborhood code: 6
# For neighborhood code BK40 , no tracts match geoid 36047150200
# 2000 SBA rate for SBA 207 is 0.5879047619047619
# 2010 SBA rate for SBA 207 is 0.6120634920634921
# 208
# Number of neighborhood codes in SBA: 2
# Neighborhood code: BK64
# Number of tracts in neighborhood code: 6
# Neighborhood code: BK61
# Number of tracts in neighborhood code: 27
# For neighborhood code BK61 , no tracts match geoid 36047027100
# For neighborhood code BK61 , no tracts match geoid 36047030500
# 2000 SBA rate for SBA 208 is 0.4915666666666667
# 2010 SBA rate for SBA 208 is 0.5937
# 209
# Number of neighborhood codes in SBA: 2
# Neighborhood code: BK60
# Number of tracts in neighborhood code: 18
# For neighborhood code BK60 , no tracts match geoid 36047079601
# For neighborhood code BK60 , no tracts match geoid 36047079602
# For neighborhood code BK60 , no tracts match geoid 36047079801
# For neighborhood code BK60 , no tracts match geoid 36047079802
# For neighborhood code BK60 , no tracts match geoid 36047080800
# Neighborhood code: BK63
# Number of tracts in neighborhood code: 9
# 2000 SBA rate for SBA 209 is 0.49239316239316244
# 2010 SBA rate for SBA 209 is 0.5561965811965811
# 210
# Number of neighborhood codes in SBA: 2
# Neighborhood code: BK31
# Number of tracts in neighborhood code: 28
# For neighborhood code BK31 , no tracts match geoid 36047004400
# For neighborhood code BK31 , no tracts match geoid 36047012600
# Neighborhood code: BK30
# Number of tracts in neighborhood code: 17
# For neighborhood code BK30 , no tracts match geoid 36047015200
# For neighborhood code BK30 , no tracts match geoid 36047016600
# 2000 SBA rate for SBA 210 is 0.6141282051282051
# 2010 SBA rate for SBA 210 is 0.6034358974358974
# 211
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BK27
# Number of tracts in neighborhood code: 11
# Neighborhood code: BK28
# Number of tracts in neighborhood code: 26
# Neighborhood code: BK29
# Number of tracts in neighborhood code: 18
# 2000 SBA rate for SBA 211 is 0.5997448847448849
# 2010 SBA rate for SBA 211 is 0.5646166796166797
# 212
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BK88
# Number of tracts in neighborhood code: 28
# Neighborhood code: BK46
# Number of tracts in neighborhood code: 9
# Neighborhood code: BK41
# Number of tracts in neighborhood code: 8
# 2000 SBA rate for SBA 212 is 0.5424735449735449
# 2010 SBA rate for SBA 212 is 0.5542857142857143
# 213
# Number of neighborhood codes in SBA: 4
# Neighborhood code: BK26
# Number of tracts in neighborhood code: 8
# For neighborhood code BK26 , no tracts match geoid 36047037401
# For neighborhood code BK26 , no tracts match geoid 36047037402
# Neighborhood code: BK19
# Number of tracts in neighborhood code: 9
# For neighborhood code BK19 , no tracts match geoid 36047061003
# For neighborhood code BK19 , no tracts match geoid 36047061004
# Neighborhood code: BK23
# Number of tracts in neighborhood code: 4
# For neighborhood code BK23 , no tracts match geoid 36047035601
# For neighborhood code BK23 , no tracts match geoid 36047035602
# Neighborhood code: BK21
# Number of tracts in neighborhood code: 8
# For neighborhood code BK21 , no tracts match geoid 36047034800
# 2000 SBA rate for SBA 213 is 0.6308333333333332
# 2010 SBA rate for SBA 213 is 0.6246428571428572
# 214
# Number of neighborhood codes in SBA: 2
# Neighborhood code: BK42
# Number of tracts in neighborhood code: 26
# For neighborhood code BK42 , no tracts match geoid 36047046000
# For neighborhood code BK42 , no tracts match geoid 36047050801
# For neighborhood code BK42 , no tracts match geoid 36047050803
# For neighborhood code BK42 , no tracts match geoid 36047050804
# For neighborhood code BK42 , no tracts match geoid 36047051001
# For neighborhood code BK42 , no tracts match geoid 36047051002
# For neighborhood code BK42 , no tracts match geoid 36047051601
# For neighborhood code BK42 , no tracts match geoid 36047051602
# For neighborhood code BK42 , no tracts match geoid 36047152200
# Neighborhood code: BK43
# Number of tracts in neighborhood code: 18
# For neighborhood code BK43 , no tracts match geoid 36047076800
# 2000 SBA rate for SBA 214 is 0.5823529411764705
# 2010 SBA rate for SBA 214 is 0.6097058823529411
# 215
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BK25
# Number of tracts in neighborhood code: 16
# Neighborhood code: BK17
# Number of tracts in neighborhood code: 19
# For neighborhood code BK17 , no tracts match geoid 36047062000
# Neighborhood code: BK44
# Number of tracts in neighborhood code: 15
# 2000 SBA rate for SBA 215 is 0.6117453703703704
# 2010 SBA rate for SBA 215 is 0.5773796296296295
# 216
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BK79
# Number of tracts in neighborhood code: 10
# Neighborhood code: BK81
# Number of tracts in neighborhood code: 15
# For neighborhood code BK81 , no tracts match geoid 36047092400
# Neighborhood code: BK85
# Number of tracts in neighborhood code: 9
# For neighborhood code BK85 , no tracts match geoid 36047114400
# 2000 SBA rate for SBA 216 is 0.47786904761904764
# 2010 SBA rate for SBA 216 is 0.5335833333333334
# 217
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BK95
# Number of tracts in neighborhood code: 7
# Neighborhood code: BK91
# Number of tracts in neighborhood code: 19
# For neighborhood code BK91 , no tracts match geoid 36047093200
# Neighborhood code: BK96
# Number of tracts in neighborhood code: 17
# For neighborhood code BK96 , no tracts match geoid 36047094600
# 2000 SBA rate for SBA 217 is 0.428587962962963
# 2010 SBA rate for SBA 217 is 0.5070271164021164
# 218
# Number of neighborhood codes in SBA: 2
# Neighborhood code: BK50
# Number of tracts in neighborhood code: 34
# For neighborhood code BK50 , no tracts match geoid 36047096000
# Neighborhood code: BK45
# Number of tracts in neighborhood code: 19
# For neighborhood code BK45 , no tracts match geoid 36047069601
# For neighborhood code BK45 , no tracts match geoid 36047069602
# 2000 SBA rate for SBA 218 is 0.5457486631016043
# 2010 SBA rate for SBA 218 is 0.5524955436720143
# 301
# Number of neighborhood codes in SBA: 3
# Neighborhood code: MN23
# Number of tracts in neighborhood code: 14
# Neighborhood code: MN24
# Number of tracts in neighborhood code: 10
# For neighborhood code MN24 , no tracts match geoid 36061003700
# Neighborhood code: MN25
# Number of tracts in neighborhood code: 7
# For neighborhood code MN25 , no tracts match geoid 36061031703
# For neighborhood code MN25 , no tracts match geoid 36061031704
# 2000 SBA rate for SBA 301 is 0.6012169312169312
# 2010 SBA rate for SBA 301 is 0.6629100529100529
# 302
# Number of neighborhood codes in SBA: 3
# Neighborhood code: MN22
# Number of tracts in neighborhood code: 7
# Neighborhood code: MN28
# Number of tracts in neighborhood code: 15
# Neighborhood code: MN27
# Number of tracts in neighborhood code: 8
# 2000 SBA rate for SBA 302 is 0.6470555555555556
# 2010 SBA rate for SBA 302 is 0.6964801587301587
# 303
# Number of neighborhood codes in SBA: 3
# Neighborhood code: MN15
# Number of tracts in neighborhood code: 7
# Neighborhood code: MN17
# Number of tracts in neighborhood code: 17
# Neighborhood code: MN13
# Number of tracts in neighborhood code: 15
# 2000 SBA rate for SBA 303 is 0.5403006535947713
# 2010 SBA rate for SBA 303 is 0.6269131652661065
# 304
# Number of neighborhood codes in SBA: 4
# Neighborhood code: MN19
# Number of tracts in neighborhood code: 11
# For neighborhood code MN19 , no tracts match geoid 36061008601
# For neighborhood code MN19 , no tracts match geoid 36061008602
# For neighborhood code MN19 , no tracts match geoid 36061008603
# Neighborhood code: MN20
# Number of tracts in neighborhood code: 7
# Neighborhood code: MN21
# Number of tracts in neighborhood code: 4
# Neighborhood code: MN50
# Number of tracts in neighborhood code: 2
# For neighborhood code MN50 , no tracts match geoid 36061004400
# 2000 SBA rate for SBA 304 is 0.6755357142857144
# 2010 SBA rate for SBA 304 is 0.7004464285714287
# 305
# Number of neighborhood codes in SBA: 2
# Neighborhood code: MN12
# Number of tracts in neighborhood code: 16
# Neighborhood code: MN14
# Number of tracts in neighborhood code: 8
# 2000 SBA rate for SBA 305 is 0.681875
# 2010 SBA rate for SBA 305 is 0.7240624999999998
# 306
# Number of neighborhood codes in SBA: 3
# Neighborhood code: MN40
# Number of tracts in neighborhood code: 14
# Neighborhood code: MN32
# Number of tracts in neighborhood code: 9
# Neighborhood code: MN31
# Number of tracts in neighborhood code: 10
# For neighborhood code MN31 , no tracts match geoid 36061023801
# For neighborhood code MN31 , no tracts match geoid 36061023802
# 2000 SBA rate for SBA 306 is 0.6508068783068783
# 2010 SBA rate for SBA 306 is 0.7004629629629631
# 307
# Number of neighborhood codes in SBA: 3
# Neighborhood code: MN04
# Number of tracts in neighborhood code: 7
# For neighborhood code MN04 , no tracts match geoid 36061022700
# For neighborhood code MN04 , no tracts match geoid 36061023100
# Neighborhood code: MN06
# Number of tracts in neighborhood code: 5
# For neighborhood code MN06 , no tracts match geoid 36061021303
# For neighborhood code MN06 , no tracts match geoid 36061021703
# Neighborhood code: MN09
# Number of tracts in neighborhood code: 10
# 2000 SBA rate for SBA 307 is 0.6841111111111111
# 2010 SBA rate for SBA 307 is 0.7074444444444445
# 308
# Number of neighborhood codes in SBA: 2
# Neighborhood code: MN11
# Number of tracts in neighborhood code: 10
# For neighborhood code MN11 , no tracts match geoid 36061025700
# Neighborhood code: MN03
# Number of tracts in neighborhood code: 16
# For neighborhood code MN03 , no tracts match geoid 36061021500
# For neighborhood code MN03 , no tracts match geoid 36061025900
# 2000 SBA rate for SBA 308 is 0.5191269841269841
# 2010 SBA rate for SBA 308 is 0.6452380952380952
# 309
# Number of neighborhood codes in SBA: 2
# Neighborhood code: MN34
# Number of tracts in neighborhood code: 11
# For neighborhood code MN34 , no tracts match geoid 36061024200
# Neighborhood code: MN33
# Number of tracts in neighborhood code: 11
# For neighborhood code MN33 , no tracts match geoid 36061017200
# 2000 SBA rate for SBA 309 is 0.6519999999999999
# 2010 SBA rate for SBA 309 is 0.7035
# 310
# Number of neighborhood codes in SBA: 3
# Neighborhood code: MN01
# Number of tracts in neighborhood code: 7
# For neighborhood code MN01 , no tracts match geoid 36061029900
# Neighborhood code: MN35
# Number of tracts in neighborhood code: 11
# Neighborhood code: MN36
# Number of tracts in neighborhood code: 12
# 2000 SBA rate for SBA 310 is 0.7429040404040403
# 2010 SBA rate for SBA 310 is 0.7535353535353534
# 401
# Number of neighborhood codes in SBA: 4
# Neighborhood code: QN72
# Number of tracts in neighborhood code: 17
# For neighborhood code QN72 , no tracts match geoid 36081010701
# For neighborhood code QN72 , no tracts match geoid 36081012301
# For neighborhood code QN72 , no tracts match geoid 36081012500
# Neighborhood code: QN71
# Number of tracts in neighborhood code: 8
# Neighborhood code: QN70
# Number of tracts in neighborhood code: 23
# For neighborhood code QN70 , no tracts match geoid 36081006501
# For neighborhood code QN70 , no tracts match geoid 36081006502
# Neighborhood code: QN68
# Number of tracts in neighborhood code: 9
# For neighborhood code QN68 , no tracts match geoid 36081003300
# For neighborhood code QN68 , no tracts match geoid 36081008500
# 2000 SBA rate for SBA 401 is 0.7017708333333335
# 2010 SBA rate for SBA 401 is 0.5968005952380953
# 402
# Number of neighborhood codes in SBA: 3
# Neighborhood code: QN31
# Number of tracts in neighborhood code: 19
# For neighborhood code QN31 , no tracts match geoid 36081017100
# For neighborhood code QN31 , no tracts match geoid 36081018101
# For neighborhood code QN31 , no tracts match geoid 36081018102
# For neighborhood code QN31 , no tracts match geoid 36081018501
# For neighborhood code QN31 , no tracts match geoid 36081018502
# For neighborhood code QN31 , no tracts match geoid 36081019900
# For neighborhood code QN31 , no tracts match geoid 36081020500
# For neighborhood code QN31 , no tracts match geoid 36081021900
# For neighborhood code QN31 , no tracts match geoid 36081025301
# For neighborhood code QN31 , no tracts match geoid 36081025302
# Neighborhood code: QN63
# Number of tracts in neighborhood code: 12
# Neighborhood code: QN50
# Number of tracts in neighborhood code: 6
# 2000 SBA rate for SBA 402 is 0.6046296296296295
# 2010 SBA rate for SBA 402 is 0.6337962962962963
# 403
# Number of neighborhood codes in SBA: 3
# Neighborhood code: QN27
# Number of tracts in neighborhood code: 8
# For neighborhood code QN27 , no tracts match geoid 36081035700
# Neighborhood code: QN28
# Number of tracts in neighborhood code: 19
# For neighborhood code QN28 , no tracts match geoid 36081030903
# For neighborhood code QN28 , no tracts match geoid 36081030904
# Neighborhood code: QN26
# Number of tracts in neighborhood code: 9
# 2000 SBA rate for SBA 403 is 0.6352287581699346
# 2010 SBA rate for SBA 403 is 0.5732306255835669
# 404
# Number of neighborhood codes in SBA: 2
# Neighborhood code: QN29
# Number of tracts in neighborhood code: 17
# For neighborhood code QN29 , no tracts match geoid 36081026901
# For neighborhood code QN29 , no tracts match geoid 36081026902
# Neighborhood code: QN25
# Number of tracts in neighborhood code: 11
# For neighborhood code QN25 , no tracts match geoid 36081043701
# For neighborhood code QN25 , no tracts match geoid 36081043702
# For neighborhood code QN25 , no tracts match geoid 36081044301
# For neighborhood code QN25 , no tracts match geoid 36081044302
# 2000 SBA rate for SBA 404 is 0.6941904761904762
# 2010 SBA rate for SBA 404 is 0.5609047619047618
# 405
# Number of neighborhood codes in SBA: 4
# Neighborhood code: QN30
# Number of tracts in neighborhood code: 14
# For neighborhood code QN30 , no tracts match geoid 36081053100
# Neighborhood code: QN21
# Number of tracts in neighborhood code: 18
# For neighborhood code QN21 , no tracts match geoid 36081060701
# For neighborhood code QN21 , no tracts match geoid 36081065501
# For neighborhood code QN21 , no tracts match geoid 36081065703
# For neighborhood code QN21 , no tracts match geoid 36081066501
# For neighborhood code QN21 , no tracts match geoid 36081066701
# For neighborhood code QN21 , no tracts match geoid 36081067100
# Neighborhood code: QN20
# Number of tracts in neighborhood code: 19
# For neighborhood code QN20 , no tracts match geoid 36081061301
# For neighborhood code QN20 , no tracts match geoid 36081061302
# Neighborhood code: QN19
# Number of tracts in neighborhood code: 13
# 2000 SBA rate for SBA 405 is 0.6732937405731523
# 2010 SBA rate for SBA 405 is 0.5698708521870287
# 406
# Number of neighborhood codes in SBA: 2
# Neighborhood code: QN17
# Number of tracts in neighborhood code: 24
# For neighborhood code QN17 , no tracts match geoid 36081071303
# For neighborhood code QN17 , no tracts match geoid 36081071304
# For neighborhood code QN17 , no tracts match geoid 36081071305
# For neighborhood code QN17 , no tracts match geoid 36081071306
# For neighborhood code QN17 , no tracts match geoid 36081072300
# For neighborhood code QN17 , no tracts match geoid 36081074900
# For neighborhood code QN17 , no tracts match geoid 36081075701
# For neighborhood code QN17 , no tracts match geoid 36081075702
# Neighborhood code: QN18
# Number of tracts in neighborhood code: 8
# For neighborhood code QN18 , no tracts match geoid 36081071701
# For neighborhood code QN18 , no tracts match geoid 36081071702
# 2000 SBA rate for SBA 406 is 0.7581249999999999
# 2010 SBA rate for SBA 406 is 0.6770833333333334
# 407
# Number of neighborhood codes in SBA: 7
# Neighborhood code: QN23
# Number of tracts in neighborhood code: 6
# Neighborhood code: QN49
# Number of tracts in neighborhood code: 8
# Neighborhood code: QN47
# Number of tracts in neighborhood code: 6
# For neighborhood code QN47 , no tracts match geoid 36081099703
# For neighborhood code QN47 , no tracts match geoid 36081099704
# For neighborhood code QN47 , no tracts match geoid 36081099705
# For neighborhood code QN47 , no tracts match geoid 36081099900
# Neighborhood code: QN51
# Number of tracts in neighborhood code: 13
# Neighborhood code: QN22
# Number of tracts in neighborhood code: 13
# For neighborhood code QN22 , no tracts match geoid 36081079701
# For neighborhood code QN22 , no tracts match geoid 36081079702
# For neighborhood code QN22 , no tracts match geoid 36081084900
# For neighborhood code QN22 , no tracts match geoid 36081086900
# Neighborhood code: QN52
# Number of tracts in neighborhood code: 12
# Neighborhood code: QN62
# Number of tracts in neighborhood code: 5
# 2000 SBA rate for SBA 407 is 0.6663956043956044
# 2010 SBA rate for SBA 407 is 0.6388653846153846
# 408
# Number of neighborhood codes in SBA: 5
# Neighborhood code: QN37
# Number of tracts in neighborhood code: 9
# For neighborhood code QN37 , no tracts match geoid 36081077906
# For neighborhood code QN37 , no tracts match geoid 36081077907
# For neighborhood code QN37 , no tracts match geoid 36081077908
# Neighborhood code: QN35
# Number of tracts in neighborhood code: 11
# Neighborhood code: QN38
# Number of tracts in neighborhood code: 7
# Neighborhood code: QN41
# Number of tracts in neighborhood code: 4
# Neighborhood code: QN06
# Number of tracts in neighborhood code: 8
# For neighborhood code QN06 , no tracts match geoid 36081127700
# 2000 SBA rate for SBA 408 is 0.6614891774891775
# 2010 SBA rate for SBA 408 is 0.659047619047619
# 409
# Number of neighborhood codes in SBA: 2
# Neighborhood code: QN53
# Number of tracts in neighborhood code: 20
# Neighborhood code: QN54
# Number of tracts in neighborhood code: 25
# 2000 SBA rate for SBA 409 is 0.59155
# 2010 SBA rate for SBA 409 is 0.5243499999999999
# 410
# Number of neighborhood codes in SBA: 3
# Neighborhood code: QN56
# Number of tracts in neighborhood code: 7
# Neighborhood code: QN57
# Number of tracts in neighborhood code: 4
# For neighborhood code QN57 , no tracts match geoid 36081006201
# For neighborhood code QN57 , no tracts match geoid 36081006202
# Neighborhood code: QN55
# Number of tracts in neighborhood code: 25
# For neighborhood code QN55 , no tracts match geoid 36081015801
# For neighborhood code QN55 , no tracts match geoid 36081015802
# 2000 SBA rate for SBA 410 is 0.5909006211180124
# 2010 SBA rate for SBA 410 is 0.5452691511387164
# 411
# Number of neighborhood codes in SBA: 4
# Neighborhood code: QN48
# Number of tracts in neighborhood code: 7
# For neighborhood code QN48 , no tracts match geoid 36081141700
# Neighborhood code: QN46
# Number of tracts in neighborhood code: 18
# For neighborhood code QN46 , no tracts match geoid 36081108500
# For neighborhood code QN46 , no tracts match geoid 36081109300
# Neighborhood code: QN42
# Number of tracts in neighborhood code: 6
# For neighborhood code QN42 , no tracts match geoid 36081129103
# For neighborhood code QN42 , no tracts match geoid 36081129104
# Neighborhood code: QN45
# Number of tracts in neighborhood code: 6
# 2000 SBA rate for SBA 411 is 0.69015625
# 2010 SBA rate for SBA 411 is 0.7224479166666666
# 412
# Number of neighborhood codes in SBA: 6
# Neighborhood code: QN02
# Number of tracts in neighborhood code: 3
# For neighborhood code QN02 , no tracts match geoid 36081029400
# Neighborhood code: QN76
# Number of tracts in neighborhood code: 16
# Neighborhood code: QN01
# Number of tracts in neighborhood code: 14
# For neighborhood code QN01 , no tracts match geoid 36081019400
# For neighborhood code QN01 , no tracts match geoid 36081025400
# Neighborhood code: QN61
# Number of tracts in neighborhood code: 15
# For neighborhood code QN61 , no tracts match geoid 36081024600
# For neighborhood code QN61 , no tracts match geoid 36081044400
# Neighborhood code: QN07
# Number of tracts in neighborhood code: 9
# Neighborhood code: QN08
# Number of tracts in neighborhood code: 23
# For neighborhood code QN08 , no tracts match geoid 36081042400
# 2000 SBA rate for SBA 412 is 0.529085971898472
# 2010 SBA rate for SBA 412 is 0.5437147921522921
# 413
# Number of neighborhood codes in SBA: 7
# Neighborhood code: QN44
# Number of tracts in neighborhood code: 5
# Neighborhood code: QN43
# Number of tracts in neighborhood code: 6
# Neighborhood code: QN34
# Number of tracts in neighborhood code: 20
# For neighborhood code QN34 , no tracts match geoid 36081053601
# For neighborhood code QN34 , no tracts match geoid 36081058200
# Neighborhood code: QN33
# Number of tracts in neighborhood code: 13
# For neighborhood code QN33 , no tracts match geoid 36081053401
# For neighborhood code QN33 , no tracts match geoid 36081062200
# Neighborhood code: QN66
# Number of tracts in neighborhood code: 11
# Neighborhood code: QN03
# Number of tracts in neighborhood code: 5
# For neighborhood code QN03 , no tracts match geoid 36081030600
# Neighborhood code: QN05
# Number of tracts in neighborhood code: 6
# 2000 SBA rate for SBA 413 is 0.5583304473304473
# 2010 SBA rate for SBA 413 is 0.6068917748917749
# 414
# Number of neighborhood codes in SBA: 3
# Neighborhood code: QN15
# Number of tracts in neighborhood code: 8
# For neighborhood code QN15 , no tracts match geoid 36081099801
# For neighborhood code QN15 , no tracts match geoid 36081099802
# For neighborhood code QN15 , no tracts match geoid 36081100801
# For neighborhood code QN15 , no tracts match geoid 36081100802
# Neighborhood code: QN12
# Number of tracts in neighborhood code: 8
# For neighborhood code QN12 , no tracts match geoid 36081095400
# For neighborhood code QN12 , no tracts match geoid 36081097203
# For neighborhood code QN12 , no tracts match geoid 36081097204
# Neighborhood code: QN10
# Number of tracts in neighborhood code: 8
# For neighborhood code QN10 , no tracts match geoid 36081093401
# For neighborhood code QN10 , no tracts match geoid 36081093402
# 2000 SBA rate for SBA 414 is 0.5670000000000001
# 2010 SBA rate for SBA 414 is 0.5877777777777777
# 501
# Number of neighborhood codes in SBA: 7
# Neighborhood code: SI12
# Number of tracts in neighborhood code: 8
# Neighborhood code: SI28
# Number of tracts in neighborhood code: 4
# Neighborhood code: SI22
# Number of tracts in neighborhood code: 12
# Neighborhood code: SI07
# Number of tracts in neighborhood code: 7
# Neighborhood code: SI35
# Number of tracts in neighborhood code: 5
# For neighborhood code SI35 , no tracts match geoid 36085006700
# Neighborhood code: SI37
# Number of tracts in neighborhood code: 8
# Neighborhood code: SI08
# Number of tracts in neighborhood code: 4
# 2000 SBA rate for SBA 501 is 0.6287074829931972
# 2010 SBA rate for SBA 501 is 0.631326530612245
# 502
# Number of neighborhood codes in SBA: 5
# Neighborhood code: SI05
# Number of tracts in neighborhood code: 9
# For neighborhood code SI05 , no tracts match geoid 36085022800
# Neighborhood code: SI24
# Number of tracts in neighborhood code: 7
# For neighborhood code SI24 , no tracts match geoid 36085018100
# For neighborhood code SI24 , no tracts match geoid 36085027705
# For neighborhood code SI24 , no tracts match geoid 36085027706
# Neighborhood code: SI14
# Number of tracts in neighborhood code: 5
# Neighborhood code: SI36
# Number of tracts in neighborhood code: 5
# Neighborhood code: SI45
# Number of tracts in neighborhood code: 5
# 2000 SBA rate for SBA 502 is 0.6598999999999999
# 2010 SBA rate for SBA 502 is 0.693
# 503
# Number of neighborhood codes in SBA: 6
# Neighborhood code: SI25
# Number of tracts in neighborhood code: 5
# For neighborhood code SI25 , no tracts match geoid 36085012805
# For neighborhood code SI25 , no tracts match geoid 36085012806
# Neighborhood code: SI54
# Number of tracts in neighborhood code: 8
# For neighborhood code SI54 , no tracts match geoid 36085014607
# For neighborhood code SI54 , no tracts match geoid 36085014608
# Neighborhood code: SI01
# Number of tracts in neighborhood code: 6
# For neighborhood code SI01 , no tracts match geoid 36085017011
# For neighborhood code SI01 , no tracts match geoid 36085017012
# For neighborhood code SI01 , no tracts match geoid 36085019800
# Neighborhood code: SI48
# Number of tracts in neighborhood code: 4
# Neighborhood code: SI32
# Number of tracts in neighborhood code: 3
# Neighborhood code: SI11
# Number of tracts in neighborhood code: 4
# For neighborhood code SI11 , no tracts match geoid 36085024401
# For neighborhood code SI11 , no tracts match geoid 36085024402
# 2000 SBA rate for SBA 503 is 0.6827777777777779
# 2010 SBA rate for SBA 503 is 0.6905555555555556
# 101
# Number of neighborhood codes in SBA: 4
# Neighborhood code: BX27
# Number of tracts in neighborhood code: 8
# For neighborhood code BX27 , no tracts match geoid 36005009300
# For neighborhood code BX27 , no tracts match geoid 36005011700
# For neighborhood code BX27 , no tracts match geoid 36005015900
# Neighborhood code: BX39
# Number of tracts in neighborhood code: 13
# For neighborhood code BX39 , no tracts match geoid 36005001900
# For neighborhood code BX39 , no tracts match geoid 36005005100
# Neighborhood code: BX34
# Number of tracts in neighborhood code: 8
# Neighborhood code: BX33
# Number of tracts in neighborhood code: 5
# 2000 SBA rate for SBA 101 is 0.6435454545454546
# 2010 SBA rate for SBA 101 is 0.6883124999999999
# 102
# Number of neighborhood codes in SBA: 4
# Neighborhood code: BX75
# Number of tracts in neighborhood code: 6
# Neighborhood code: BX01
# Number of tracts in neighborhood code: 8
# For neighborhood code BX01 , no tracts match geoid 36005014701
# For neighborhood code BX01 , no tracts match geoid 36005014702
# For neighborhood code BX01 , no tracts match geoid 36005039500
# Neighborhood code: BX17
# Number of tracts in neighborhood code: 12
# For neighborhood code BX17 , no tracts match geoid 36005037504
# Neighborhood code: BX75
# Number of tracts in neighborhood code: 6
# 2000 SBA rate for SBA 102 is 0.5994848484848485
# 2010 SBA rate for SBA 102 is 0.6481060606060605
# 103
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BX14
# Number of tracts in neighborhood code: 14
# For neighborhood code BX14 , no tracts match geoid 36005017701
# For neighborhood code BX14 , no tracts match geoid 36005017702
# For neighborhood code BX14 , no tracts match geoid 36005017901
# For neighborhood code BX14 , no tracts match geoid 36005017902
# For neighborhood code BX14 , no tracts match geoid 36005018101
# For neighborhood code BX14 , no tracts match geoid 36005018102
# For neighborhood code BX14 , no tracts match geoid 36005018301
# For neighborhood code BX14 , no tracts match geoid 36005018302
# Neighborhood code: BX63
# Number of tracts in neighborhood code: 7
# For neighborhood code BX63 , no tracts match geoid 36005006300
# For neighborhood code BX63 , no tracts match geoid 36005020900
# For neighborhood code BX63 , no tracts match geoid 36005022101
# For neighborhood code BX63 , no tracts match geoid 36005022102
# Neighborhood code: BX26
# Number of tracts in neighborhood code: 7
# 2000 SBA rate for SBA 103 is 0.6498412698412698
# 2010 SBA rate for SBA 103 is 0.6984126984126985
# 104
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BX36
# Number of tracts in neighborhood code: 14
# For neighborhood code BX36 , no tracts match geoid 36005005300
# For neighborhood code BX36 , no tracts match geoid 36005020501
# For neighborhood code BX36 , no tracts match geoid 36005020502
# For neighborhood code BX36 , no tracts match geoid 36005021700
# For neighborhood code BX36 , no tracts match geoid 36005024501
# For neighborhood code BX36 , no tracts match geoid 36005024502
# For neighborhood code BX36 , no tracts match geoid 36005024900
# Neighborhood code: BX41
# Number of tracts in neighborhood code: 13
# Neighborhood code: BX40
# Number of tracts in neighborhood code: 5
# For neighborhood code BX40 , no tracts match geoid 36005023703
# For neighborhood code BX40 , no tracts match geoid 36005023704
# For neighborhood code BX40 , no tracts match geoid 36005038301
# For neighborhood code BX40 , no tracts match geoid 36005038302
# 2000 SBA rate for SBA 104 is 0.6073260073260073
# 2010 SBA rate for SBA 104 is 0.6564835164835165
# 105
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BX43
# Number of tracts in neighborhood code: 7
# Neighborhood code: BX05
# Number of tracts in neighborhood code: 11
# For neighborhood code BX05 , no tracts match geoid 36005040501
# For neighborhood code BX05 , no tracts match geoid 36005040502
# Neighborhood code: BX30
# Number of tracts in neighborhood code: 6
# 2000 SBA rate for SBA 105 is 0.5983862433862434
# 2010 SBA rate for SBA 105 is 0.6752645502645503
# 106
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BX22
# Number of tracts in neighborhood code: 9
# For neighborhood code BX22 , no tracts match geoid 36005030701
# For neighborhood code BX22 , no tracts match geoid 36005030900
# For neighborhood code BX22 , no tracts match geoid 36005031900
# For neighborhood code BX22 , no tracts match geoid 36005033500
# For neighborhood code BX22 , no tracts match geoid 36005033700
# Neighborhood code: BX29
# Number of tracts in neighborhood code: 9
# For neighborhood code BX29 , no tracts match geoid 36005029301
# For neighborhood code BX29 , no tracts match geoid 36005029302
# Neighborhood code: BX28
# Number of tracts in neighborhood code: 10
# For neighborhood code BX28 , no tracts match geoid 36005026701
# For neighborhood code BX28 , no tracts match geoid 36005026702
# For neighborhood code BX28 , no tracts match geoid 36005040303
# For neighborhood code BX28 , no tracts match geoid 36005040304
# 2000 SBA rate for SBA 106 is 0.6677777777777778
# 2010 SBA rate for SBA 106 is 0.7148412698412699
# 107
# Number of neighborhood codes in SBA: 5
# Neighborhood code: BX08
# Number of tracts in neighborhood code: 7
# For neighborhood code BX08 , no tracts match geoid 36005007600
# Neighborhood code: BX46
# Number of tracts in neighborhood code: 5
# For neighborhood code BX46 , no tracts match geoid 36005021001
# For neighborhood code BX46 , no tracts match geoid 36005021002
# For neighborhood code BX46 , no tracts match geoid 36005022200
# Neighborhood code: BX59
# Number of tracts in neighborhood code: 7
# For neighborhood code BX59 , no tracts match geoid 36005009600
# Neighborhood code: BX55
# Number of tracts in neighborhood code: 9
# For neighborhood code BX55 , no tracts match geoid 36005005001
# For neighborhood code BX55 , no tracts match geoid 36005005002
# Neighborhood code: BX09
# Number of tracts in neighborhood code: 12
# For neighborhood code BX09 , no tracts match geoid 36005004200
# For neighborhood code BX09 , no tracts match geoid 36005009000
# 2000 SBA rate for SBA 107 is 0.5766666666666667
# 2010 SBA rate for SBA 107 is 0.6261619047619048
# 108
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BX13
# Number of tracts in neighborhood code: 3
# Neighborhood code: BX10
# Number of tracts in neighborhood code: 6
# For neighborhood code BX10 , no tracts match geoid 36005027401
# For neighborhood code BX10 , no tracts match geoid 36005027402
# Neighborhood code: BX52
# Number of tracts in neighborhood code: 15
# For neighborhood code BX52 , no tracts match geoid 36005015200
# 2000 SBA rate for SBA 108 is 0.5684126984126985
# 2010 SBA rate for SBA 108 is 0.6294444444444444
# 109
# Number of neighborhood codes in SBA: 4
# Neighborhood code: BX31
# Number of tracts in neighborhood code: 11
# For neighborhood code BX31 , no tracts match geoid 36005032600
# For neighborhood code BX31 , no tracts match geoid 36005034800
# For neighborhood code BX31 , no tracts match geoid 36005036000
# Neighborhood code: BX07
# Number of tracts in neighborhood code: 8
# For neighborhood code BX07 , no tracts match geoid 36005033201
# For neighborhood code BX07 , no tracts match geoid 36005033202
# Neighborhood code: BX49
# Number of tracts in neighborhood code: 9
# For neighborhood code BX49 , no tracts match geoid 36005022403
# For neighborhood code BX49 , no tracts match geoid 36005022404
# Neighborhood code: BX37
# Number of tracts in neighborhood code: 12
# For neighborhood code BX37 , no tracts match geoid 36005020000
# For neighborhood code BX37 , no tracts match geoid 36005023800
# 2000 SBA rate for SBA 109 is 0.5665535714285714
# 2010 SBA rate for SBA 109 is 0.5826220238095238
# 110
# Number of neighborhood codes in SBA: 3
# Neighborhood code: BX62
# Number of tracts in neighborhood code: 14
# For neighborhood code BX62 , no tracts match geoid 36005043400
# For neighborhood code BX62 , no tracts match geoid 36005044400
# Neighborhood code: BX44
# Number of tracts in neighborhood code: 20
# Neighborhood code: BX03
# Number of tracts in neighborhood code: 8
# For neighborhood code BX03 , no tracts match geoid 36005045600
# 2000 SBA rate for SBA 110 is 0.46411111111111114
# 2010 SBA rate for SBA 110 is 0.5352936507936508

# %%
# Save responses rates by SBA for 2000 and 2010
# just_sbas_and_rates_2000 = dataset2000['sba_response_rate_2000']
# just_sbas_and_rates_2010 = dataset2010['sba_response_rate_2010']
# just_sbas_and_rates_2000.to_csv('SBA_Rates_2000.csv')
# just_sbas_and_rates_2010.to_csv('SBA_Rates_2010.csv')

# %%
# BIG NOTE: POTENTIALLY INACCURATE DUE TO ERRORS SEEN IN PRINTOUT ABOVE
# BIG NOTE: Fills in NaN vals with average value in that category in order to make the random forest
# Random Forest Model: Trained and tested on 2000 data

# Forming training and testing sets and replace NaN with mean
k = len(dataset2000.columns) - 1
tens_feats = tens_w_nineties.set_index('sub-burough').iloc[:,1:k].values
X = dataset2000.iloc[:,1:k].values
y = dataset2000.iloc[:,k].values

from sklearn.preprocessing import Imputer
imp = Imputer(missing_values=np.nan, strategy='mean')
imp = imp.fit(tens_feats) # fit imputer to tens_feats so that number of features will match up for prediction later
X = imp.transform(X)

from sklearn.model_selection import train_test_split

# test_size=0.2 -> Training with 4/5 of data to test on the remaining 1/5
# random_state=0 for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


# Feature Scaling: This is optional, we can compare scaling vs. not scaling and see what's better
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)


# Train the random forest
# Set random_state for reproducibility
# Can change n_estimators to see best performance
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=200, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)


# Evaluate model
from sklearn import metrics

print('2000 Census Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('2000 Census Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('2000 Census Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 2000 Census Mean Absolute Error: 0.06328008304429798
# 2000 Census Mean Squared Error: 0.005936164684902409
# 2000 Census Root Mean Squared Error: 0.07704650988138534

# %%
# Feature importances (with indices) in 2000
feat_importances = enumerate(regressor.feature_importances_)

# Top n important features in 2000
n = 10 # defaults to top 10
k = len(dataset2000.columns) - 1
ranked_feat_importances = sorted(feat_importances, key=lambda x:x[1]) # ascending sort
for i in range(1,n+1):
    index, importance = ranked_feat_importances[-i]
    feat = list(dataset2000.iloc[:,1:k].columns)[index]
    print("Rank",i,"most important feature for 2000 data is",feat,", with importance value",importance)
# Out:
# Rank 1 most important feature for 2000 data is 1989.0_delta_2 , with importance value 0.06452560850812666
# Rank 2 most important feature for 2000 data is _delta_1 , with importance value 0.05412723400984821
# Rank 3 most important feature for 2000 data is 'chinese', 'viet'_delta_1 , with importance value 0.05179744354404514
# Rank 4 most important feature for 2000 data is Excellent_delta_2 , with importance value 0.04248714494139699
# Rank 5 most important feature for 2000 data is 2001_delta_3 , with importance value 0.026376446805979427
# Rank 6 most important feature for 2000 data is 'white', 'black', 'chinese'_delta_2 , with importance value 0.026196197203403274
# Rank 7 most important feature for 2000 data is 'Kor', 'asian-ind'_delta_1 , with importance value 0.02482607799632863
# Rank 8 most important feature for 2000 data is pctnt_recent_1999_delta_1 , with importance value 0.02328365698220781
# Rank 9 most important feature for 2000 data is black_delta_2 , with importance value 0.021684921532006227
# Rank 10 most important feature for 2000 data is amind_delta_2 , with importance value 0.020765260985822254

# %%
# TO DO
# Check slides 27, 28
# Response rates by SBA for the predictions from each model
# Check python documentation for ROC Curve and maybe also confusion matrix, maybe precision-recall

# %%
# 2020 predictions using model trained on 90s features
k = len(dataset2000.columns) - 1
indexed_feats = tens_w_nineties.set_index('sub-burough')
tens_feats = tens_w_nineties.set_index('sub-burough').iloc[:,1:k].values

# Deal with NaNs
tens_feats = imp.transform(tens_feats)

# Feature Scaling: This is optional, we can compare scaling vs. not scaling and see what's better
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
tens_feats = sc.fit_transform(tens_feats)

preds_2020 = list(regressor.predict(tens_feats))
pred_from_90s = enumerate(preds_2020)

# Bottom n SBAs by predicted response rate Census 2020
n = 10 # defaults to bottom 10
ranked_rates = sorted(pred_from_90s, key=lambda x:x[1], reverse=True) # descending sort

for i in range(1,n+1):
    index, pred_rate = ranked_rates[-i]
    sba = str(list(indexed_feats.index)[index])
    print("Rank",i,"lowest predicted response rate SBA based on 2000 data is SBA",sba,
          ", with predicted response rate",pred_rate)

# Save predicted responses rates by SBA for 2020 from model trained on 2000 data
indexed_feats['preds_2020'] = preds_2020
sbas_and_preds = indexed_feats['preds_2020']
sbas_and_preds.to_csv('Predicted_SBA_Rates_2000_model.csv')
# Out:
# Rank 1 lowest predicted response rate SBA based on 2000 data is SBA 409 , with predicted response rate 0.5802390833473324
# Rank 2 lowest predicted response rate SBA based on 2000 data is SBA 501 , with predicted response rate 0.5809059084812196
# Rank 3 lowest predicted response rate SBA based on 2000 data is SBA 214 , with predicted response rate 0.5826765176509963
# Rank 4 lowest predicted response rate SBA based on 2000 data is SBA 410 , with predicted response rate 0.5831084634097502
# Rank 5 lowest predicted response rate SBA based on 2000 data is SBA 412 , with predicted response rate 0.5844223323275799
# Rank 6 lowest predicted response rate SBA based on 2000 data is SBA 109 , with predicted response rate 0.5844933818620975
# Rank 7 lowest predicted response rate SBA based on 2000 data is SBA 218 , with predicted response rate 0.5846141157395395
# Rank 8 lowest predicted response rate SBA based on 2000 data is SBA 107 , with predicted response rate 0.5850824785279647
# Rank 9 lowest predicted response rate SBA based on 2000 data is SBA 110 , with predicted response rate 0.5851310745632649
# Rank 10 lowest predicted response rate SBA based on 2000 data is SBA 403 , with predicted response rate 0.5859014854134209

# %%
# BIG NOTE: POTENTIALLY INACCURATE DUE TO ERRORS SEEN IN PRINTOUT ABOVE
# BIG NOTE: Fills in NaN vals with average value in that category in order to make the random forest
# Random Forest Model: Trained and tested on 2010 data

# Forming training and testing sets and replace NaN with mean
k = len(dataset2010.columns) - 1
tens_feats = tens_w_thousands.set_index('sub-burough').iloc[:,1:k].values
X = dataset2010.iloc[:,1:k].values
y = dataset2010.iloc[:,k].values

from sklearn.preprocessing import Imputer
imp = Imputer(missing_values=np.nan, strategy='mean')
imp = imp.fit(tens_feats) # fit imputer to tens_feats so that number of features will match up for prediction later
X = imp.transform(X)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


# Feature Scaling: This is optional, we can compare scaling vs. not scaling and see what's better
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)


# Train the random forest
# Set random_state for reproducibility
# Can change n_estimators to see best performance
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=200, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)


# Evaluate model
from sklearn import metrics

print('2010 Census Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('2010 Census Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('2010 Census Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 2010 Census Mean Absolute Error: 0.05237622742251183
# 2010 Census Mean Squared Error: 0.0033534021425956333
# 2010 Census Root Mean Squared Error: 0.05790856709154211

# %%
# Feature importances (with indices) in 2010
feat_importances = enumerate(regressor.feature_importances_)
feat_indices = []

# Top n important features in 2010
n = 10 # default to top 10
k = len(dataset2010.columns) - 1
ranked_feat_importances = sorted(feat_importances, key=lambda x:x[1]) # ascending sort
for i in range(1,n+1):
    index, importance = ranked_feat_importances[-i]
    feat_indices.append(index)
    feat = list(dataset2010.iloc[:,1:k].columns)[index]
    print("Rank",i,"most important feature for 2010 data is",feat,", with importance value",importance)
# Out:
# Rank 1 most important feature for 2010 data is 2004_delta_1 , with importance value 0.16500833832550227
# Rank 2 most important feature for 2010 data is 2005_delta_3 , with importance value 0.06655909259187784
# Rank 3 most important feature for 2010 data is std_value_delta_1 , with importance value 0.05787849878364259
# Rank 4 most important feature for 2010 data is 31_delta_2 , with importance value 0.054775337196144046
# Rank 5 most important feature for 2010 data is 1_delta_1 , with importance value 0.035202472501095074
# Rank 6 most important feature for 2010 data is 2003_delta_1 , with importance value 0.0328850879184618
# Rank 7 most important feature for 2010 data is 1988.0_delta_1 , with importance value 0.02179831654943404
# Rank 8 most important feature for 2010 data is mean_income_delta_1 , with importance value 0.020492770145899807
# Rank 9 most important feature for 2010 data is pctnt_recent_1991_delta_2 , with importance value 0.018789313599816223
# Rank 10 most important feature for 2010 data is 'white', 'chinese'_delta_2 , with importance value 0.01775437259538428

# %%
# 2020 predictions using model trained with 00s features
k = len(dataset2010.columns) - 1
indexed_feats = tens_w_thousands.set_index('sub-burough')
tens_feats = tens_w_thousands.set_index('sub-burough').iloc[:,1:k].values

# Deal with NaNs
tens_feats = imp.transform(tens_feats)

# Feature Scaling: This is optional, we can compare scaling vs. not scaling and see what's better
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
tens_feats = sc.fit_transform(tens_feats)

preds_2020 = regressor.predict(tens_feats)
pred_from_00s = enumerate(preds_2020)

# Bottom n SBAs by predicted response rate Census 2020
n = 10 # defaults to bottom 10
ranked_rates = sorted(pred_from_00s, key=lambda x:x[1], reverse=True) # descending sort
for i in range(1,n+1):
    index, pred_rate = ranked_rates[-i]
    sba = str(list(indexed_feats.index)[index])
    print("Rank",i,"lowest response rate SBA for 2010 data is SBA",sba,", with predicted response rate",pred_rate)
    
# Save predicted responses rates by SBA for 2020 from model trained on 2010 data
indexed_feats['preds_2020'] = preds_2020
sbas_and_preds = indexed_feats['preds_2020']
sbas_and_preds.to_csv('Predicted_SBA_Rates_2010_model.csv')
# Out:
# Rank 1 lowest response rate SBA for 2010 data is SBA 308 , with predicted response rate 0.5888653160794859
# Rank 2 lowest response rate SBA for 2010 data is SBA 410 , with predicted response rate 0.5910226130908496
# Rank 3 lowest response rate SBA for 2010 data is SBA 305 , with predicted response rate 0.5920356163993876
# Rank 4 lowest response rate SBA for 2010 data is SBA 302 , with predicted response rate 0.5935308904467711
# Rank 5 lowest response rate SBA for 2010 data is SBA 110 , with predicted response rate 0.6014560621503904
# Rank 6 lowest response rate SBA for 2010 data is SBA 403 , with predicted response rate 0.6021841737194458
# Rank 7 lowest response rate SBA for 2010 data is SBA 202 , with predicted response rate 0.6025614305772403
# Rank 8 lowest response rate SBA for 2010 data is SBA 413 , with predicted response rate 0.6035589340029346
# Rank 9 lowest response rate SBA for 2010 data is SBA 203 , with predicted response rate 0.6058357715133263
# Rank 10 lowest response rate SBA for 2010 data is SBA 404 , with predicted response rate 0.607486013300356
